# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/icia_colab_git
#내 Gogle Drive에 git 연동 폴더 생성(여기서 내 경우 icia_colab_git)
#오른쪽 폴더 모양 클릭 후 해당 경로에 설치한 폴더 옆에 ... 아이콘 클릭 후 경로 복사
#cd 명령어 입력하여 폴더 생성 여부 확인 경로 뜨면 폴더 설치 완료
# Out:
# /content/drive/MyDrive/Colab Notebooks/icia_colab_git

# %%
# !git clone https://(user name):(token)@github.com/(user name)/(repository file name).git
#(user name) : github 프로필 이름 입력(가입 이메일 X), ()빼고 값만 입력
#(token): 토큰 값 입력
#(repository file name): github에 만든 폴더명 입력

# %% [markdown]
# 성공시 결과 예시
#
# Cloning into 'icia_colab'...
#
# remote: Enumerating objects: 3, done.
#
# remote: Counting objects: 100% (3/3), done.
#
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
#
# Unpacking objects: 100% (3/3), 592 bytes | 19.00 KiB/s, done.

# %%
cd icia_colab/
#/content/drive/MyDrive/Colab Notebooks/icia_colab_git/icia_colab
#git 연동 폴더 경로 확인

# %%
# !git config --global user.email 'github email'
# !git config --global user.name 'profile name'

# %%
# !git status
#github 올리기 전 stage에 올라가있는 파일 확인 
#아래 실행 예 lol_champ_tags.ipynb가 stage에 올라가 있음 
#error 날 시 파일명 공백, 한글 사용 여부등 확인 해 볼 것

# %% [markdown]
# On branch main
#
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#
#   (use "git add <file>..." to include in what will be committed)
#
# 	lol_champ_tags.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git lol_champ_tags.ipynb
# !git commit -m "Connect Google Colab and Drive"
#커밋 명령어

# %%
# !git push -u origin main
#최종 푸시 
#아래 성공 예

# %% [markdown]
# Enumerating objects: 4, done.
#
# Counting objects: 100% (4/4), done.
#
# Delta compression using up to 2 threads
#
# Compressing objects: 100% (3/3), done.
#
# Writing objects: 100% (3/3), 3.42 MiB | 4.84 MiB/s, done.
#
# Total 3 (delta 1), reused 0 (delta 0)
#
# remote: Resolving deltas: 100% (1/1), completed with 1
# local object.
#
# To https://github.com/
#
#    07880a0..403ecfb  main -> main
#
# Branch 'main' set up to track remote branch 'main' from 'origin'.
